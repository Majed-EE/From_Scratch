# %%
# fine tuning a large language models

# %%
import torch
from torch import nn

# %%
# 3 ways to fine tune
# self superised, superised and reinforcement learning
# supervised fine tuning 5 steps
# step 1: chose a fine tuning task
# step 2: prepare the dataset
# step 3: choose a pre trained model
# step 4: define the training loop to fine tune the model via supervised learning
# step 5: evaluate the model

# 3 options for parameter training
# 1. full fine tuning
# 2. transfer learning
# 3. Parameter efficient fine tuning (PEFT) - we augment the model with additional 
# trainable parameters while keeping the original model's parameters frozen.
# PEFT techniques include adapters, LoRA (Low-Rank Adaptation), and prefix tuning.

# %%
from datasets import load_dataset, DatasetDict, Dataset

# %%
from transformers import (AutoTokenizer, AutoConfig, 
                          AutoModelForSequenceClassification, DataCollatorWithPadding,
                          Trainer, TrainingArguments)

from peft import PeftModel
from peft import PeftConfig 
from peft import get_peft_model 
from peft import LoraConfig
import evaluate
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 5
#       1 from transformers import (AutoTokenizer, AutoConfig,
#       2                           AutoModelForSequenceClassification, DataCollatorWithPadding,
#       3                           Trainer, TrainingArguments)
# ----> 5 from peft import PeftModel
#       6 from peft import PeftConfig
#       7 from peft import get_peft_model
#
# File ~/.local/lib/python3.10/site-packages/peft/__init__.py:22
#       1 # flake8: noqa
#       2 # There's no way to ignore "F401 '...' imported but unused" warnings in this
#       3 # module, but to preserve other warnings. So, don't check this module at all.
#    (...)
#      17 # See the License for the specific language governing permissions and
#      18 # limitations under the License.
#      20 __version__ = "0.10.0"
# ---> 22 from .auto import (
# ...

# %%
model_checkpoint = "distilbert-base-uncased"

# Define label maps
id2label = {0: "NEGATIVE", 1: "POSITIVE"}
label2id = {"NEGATIVE": 0, "POSITIVE": 1}

# Generate classification model from model_checkpoint
model = AutoModelForSequenceClassification.from_pretrained(
    model_checkpoint,
    num_labels=2,
    id2label=id2label,
    label2id=label2id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 8
#       5 label2id = {"NEGATIVE": 0, "POSITIVE": 1}
#       7 # Generate classification model from model_checkpoint
# ----> 8 model = AutoModelForSequenceClassification.from_pretrained(
#       9     model_checkpoint,
#      10     num_labels=2,
#      11     id2label=id2label,
#      12     label2id=label2id)
#
# NameError: name 'AutoModelForSequenceClassification' is not defined
